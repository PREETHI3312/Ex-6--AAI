# %%
import nltk
from nltk.corpus import wordnet

# Downloads
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

sentence = input("Enter a sentence: ")

# Simple tokenization
words = sentence.split()

# POS tagging
pos_tags = nltk.pos_tag(words)

synonyms = []
antonyms = []

for word in words:
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.append(lemma.name())

            if lemma.antonyms():
                antonyms.append(lemma.antonyms()[0].name())

print("POS Tags:", pos_tags)
print("Synonyms:", set(synonyms))
print("Antonyms:", set(antonyms))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# Enter a sentence: hi how are you
# POS Tags: [('hi', 'VB'), ('how', 'WRB'), ('are', 'VBP'), ('you', 'PRP')]
# Synonyms: {'hello', 'how-do-you-do', "Hawai'i", 'be', 'howdy', 'equal', 'make_up', 'personify', 'HI', 'are', 'exist', 'follow', 'cost', 'live', 'constitute', 'hullo', 'represent', 'Aloha_State', 'hi', 'ar', 'comprise', 'embody', 'Hawaii'}
# Antonyms: {'differ'}
